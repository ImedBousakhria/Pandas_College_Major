# %% [markdown]
# # First Test

# %%
######

# %%
import pandas as pd

# %%
df = pd.read_csv('salaries_by_college_major.csv')

# %%
df.head()

# %%
df.shape
# Out:
# (51, 6)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.isna()

# %%
df.tail()

# %%
clean_df = df.dropna()

# %%
clean_df.tail()

# %%
clean_df["Starting Median Salary"].max()
# Out:
# 74300.0

# %%
clean_df['Starting Median Salary'].idxmax()
# Out:
# 43

# %%
clean_df['Undergraduate Major'][43]
# Out:
# 'Physician Assistant'

# %%
clean_df
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
clean_df['Undergraduate Major'][(clean_df['Mid-Career Median Salary'].idxmax())]
# Out:
# 107000.0

# %%
clean_df['Mid-Career Median Salary'].max()
# Out:
# 107000.0

# %%
clean_df['Undergraduate Major'][(clean_df['Starting Median Salary'].idxmin())]
# Out:
# 'Spanish'

# %%
clean_df['Undergraduate Major'][clean_df['Undergraduate Major'] == 'Spanish']
# Out:
# 49    Spanish
# Name: Undergraduate Major, dtype: object

# %%
clean_df['Starting Median Salary'].min()
# Out:
# 34000.0

# %% [markdown]
# # Challenge question 3

# %%
clean_df['Undergraduate Major'][(clean_df['Mid-Career Median Salary'].idxmin())]
# Out:
# 'Education'

# %%
clean_df['Mid-Career 90th Percentile Salary'][clean_df['Undergraduate Major'] == 'Education']
# Out:
# 18    102000.0
# Name: Mid-Career 90th Percentile Salary, dtype: float64

# %% [markdown]
# Teachers should expect to earn this much :

# %%
clean_df[clean_df['Undergraduate Major'] == 'Education']
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 18           Education                 34900.0                   52000.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 18                            29300.0                           102000.0  HASS

# %% [markdown]
# (another method)

# %%
clean_df.loc[clean_df['Mid-Career Median Salary'].idxmin()]
# Out:
# Undergraduate Major                  Education
# Starting Median Salary                 34900.0
# Mid-Career Median Salary               52000.0
# Mid-Career 10th Percentile Salary      29300.0
# Mid-Career 90th Percentile Salary     102000.0
# Group                                     HASS
# Name: 18, dtype: object

# %%
clean_df

# %%
spread_col = clean_df['Mid-Career 90th Percentile Salary'].subtract(clean_df['Mid-Career 10th Percentile Salary'])

# %%
sorted_df = clean_df.sort_values('Spread')

# %%
sorted_df[['Undergraduate Major', 'Spread']].head()

# %% [markdown]
# # Challenge part 8

# %%
myDf = clean_df.sort_values('Mid-Career 90th Percentile Salary' ,ascending=False)

# %%
myDf[['Undergraduate Major', 'Mid-Career 90th Percentile Salary']].head()
# Out:
#      Undergraduate Major  Mid-Career 90th Percentile Salary
# 17             Economics                           210000.0
# 22               Finance                           195000.0
# 8   Chemical Engineering                           194000.0
# 37                  Math                           183000.0
# 44               Physics                           178000.0

# %%
clean_df.sort_values('Spread', ascending=False)[['Undergraduate Major', 'Spread']].head()
# Out:
#    Undergraduate Major    Spread
# 17           Economics  159400.0
# 22             Finance  147800.0
# 37                Math  137800.0
# 36           Marketing  132900.0
# 42          Philosophy  132500.0

# %% [markdown]
# ---
#
#
#
# # Part 9
#
# ---

# %%
clean_df.groupby('Group').count()
# Out:
#           Undergraduate Major  Spread  Starting Median Salary  \
# Group
# Business                   12      12                      12
# HASS                       22      22                      22
# STEM                       16      16                      16
#
#           Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# Group
# Business                        12                                 12
# HASS                            22                                 22
# STEM                            16                                 16
#
#           Mid-Career 90th Percentile Salary
# Group
# Business                                 12
# HASS                                     22
# STEM                                     16

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
clean_df.groupby('Group').mean()
# Out:
# <ipython-input-57-61aa9b47bd8a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   clean_df.groupby('Group').mean()
#              Spread  Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business 103,958.33               44,633.33                 75,083.33
# HASS      95,218.18               37,186.36                 62,968.18
# STEM     101,600.00               53,862.50                 90,812.50
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                          43,566.67                         147,525.00
# HASS                              34,145.45                         129,363.64
# STEM                              56,025.00                         157,625.00
